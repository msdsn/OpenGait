# %% [markdown]
# <a href="https://colab.research.google.com/github/msdsn/OpenGait/blob/master/Resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
# !gdown 1d-DGCtaex6YZNg2ad2aPzRWW0xn4bVj3
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1d-DGCtaex6YZNg2ad2aPzRWW0xn4bVj3
# From (redirected): https://drive.google.com/uc?id=1d-DGCtaex6YZNg2ad2aPzRWW0xn4bVj3&confirm=t&uuid=7ece6bf9-4e29-4b3c-a4b4-e72646703bd0
# To: /content/GaitDatasetB-silh.zip
# 100% 659M/659M [00:02<00:00, 240MB/s]

# %%
# !unzip "/content/GaitDatasetB-silh.zip" -d "/content/GaitDatasetB"
# Out:
# Archive:  /content/GaitDatasetB-silh.zip
#    creating: /content/GaitDatasetB/GaitDatasetB-silh/
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/001.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/002.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/003.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/004.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/005.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/006.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/007.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/008.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/009.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/010.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/011.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/012.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/013.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/014.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/015.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/016.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/017.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/018.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/019.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/020.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/021.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/022.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/023.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/024.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/025.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/026.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/027.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/028.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/029.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/030.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/031.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/032.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/033.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/034.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/035.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/036.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/037.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/038.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/039.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/040.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/041.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/042.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/043.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/044.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/045.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/046.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/047.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/048.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/049.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/050.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/051.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/052.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/053.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/054.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/055.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/056.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/057.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/058.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/059.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/060.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/061.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/062.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/063.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/064.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/065.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/066.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/067.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/068.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/069.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/070.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/071.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/072.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/073.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/074.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/075.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/076.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/077.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/078.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/079.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/080.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/081.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/082.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/083.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/084.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/085.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/086.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/087.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/088.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/089.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/090.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/091.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/092.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/093.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/094.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/095.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/096.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/097.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/098.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/099.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/100.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/101.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/102.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/103.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/104.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/105.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/106.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/107.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/108.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/109.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/110.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/111.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/112.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/113.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/114.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/115.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/116.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/117.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/118.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/119.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/120.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/121.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/122.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/123.tar.gz
#  extracting: /content/GaitDatasetB/GaitDatasetB-silh/124.tar.gz

# %%
import tarfile
import os

def unzip_tar_gz(folder_path):
  for filename in os.listdir(folder_path):
    if filename.endswith(".tar.gz"):
      filepath = os.path.join(folder_path, filename)
      try:
        with tarfile.open(filepath, "r:gz") as tar:
          tar.extractall(folder_path)
          print(f"Extracted: {filename}")
        # remove tar.gz
        os.remove(filepath)
      except Exception as e:
        print(f"Error extracting {filename}: {e}")

unzip_tar_gz("/content/GaitDatasetB/GaitDatasetB-silh")
# Out:
# Extracted: 037.tar.gz
# Extracted: 069.tar.gz
# Extracted: 098.tar.gz
# Extracted: 028.tar.gz
# Extracted: 055.tar.gz
# Extracted: 064.tar.gz
# Extracted: 020.tar.gz
# Extracted: 096.tar.gz
# Extracted: 029.tar.gz
# Extracted: 075.tar.gz
# Extracted: 106.tar.gz
# Extracted: 033.tar.gz
# Extracted: 012.tar.gz
# Extracted: 019.tar.gz
# Extracted: 115.tar.gz
# Extracted: 102.tar.gz
# Extracted: 082.tar.gz
# Extracted: 022.tar.gz
# Extracted: 031.tar.gz
# Extracted: 121.tar.gz
# Extracted: 085.tar.gz
# Extracted: 099.tar.gz
# Extracted: 005.tar.gz
# Extracted: 067.tar.gz
# Extracted: 092.tar.gz
# Extracted: 065.tar.gz
# Extracted: 058.tar.gz
# Extracted: 021.tar.gz
# Extracted: 110.tar.gz
# Extracted: 041.tar.gz
# Extracted: 040.tar.gz
# Extracted: 027.tar.gz
# Extracted: 111.tar.gz
# Extracted: 088.tar.gz
# Extracted: 076.tar.gz
# Extracted: 018.tar.gz
# Extracted: 001.tar.gz
# Extracted: 090.tar.gz
# Extracted: 046.tar.gz
# Extracted: 089.tar.gz
# Extracted: 068.tar.gz
# Extracted: 042.tar.gz
# Extracted: 094.tar.gz
# Extracted: 091.tar.gz
# Extracted: 107.tar.gz
# Extracted: 050.tar.gz
# Extracted: 060.tar.gz
# Extracted: 123.tar.gz
# Extracted: 007.tar.gz
# Extracted: 062.tar.gz
# Extracted: 002.tar.gz
# Extracted: 044.tar.gz
# Extracted: 103.tar.gz
# Extracted: 054.tar.gz
# Extracted: 113.tar.gz
# Extracted: 006.tar.gz
# Extracted: 048.tar.gz
# Extracted: 080.tar.gz
# Extracted: 023.tar.gz
# Extracted: 120.tar.gz
# Extracted: 051.tar.gz
# Extracted: 109.tar.gz
# Extracted: 034.tar.gz
# Extracted: 030.tar.gz
# Extracted: 032.tar.gz
# Extracted: 077.tar.gz
# Extracted: 003.tar.gz
# Extracted: 013.tar.gz
# Extracted: 122.tar.gz
# Extracted: 039.tar.gz
# Extracted: 105.tar.gz
# Extracted: 026.tar.gz
# Extracted: 101.tar.gz
# Extracted: 052.tar.gz
# Extracted: 104.tar.gz
# Extracted: 118.tar.gz
# Extracted: 057.tar.gz
# Extracted: 036.tar.gz
# Extracted: 116.tar.gz
# Extracted: 117.tar.gz
# Extracted: 086.tar.gz
# Extracted: 084.tar.gz
# Extracted: 078.tar.gz
# Extracted: 016.tar.gz
# Extracted: 097.tar.gz
# Extracted: 073.tar.gz
# Extracted: 045.tar.gz
# Extracted: 093.tar.gz
# Extracted: 124.tar.gz
# Extracted: 038.tar.gz
# Extracted: 095.tar.gz
# Extracted: 025.tar.gz
# Extracted: 081.tar.gz
# Extracted: 079.tar.gz
# Extracted: 035.tar.gz
# Extracted: 024.tar.gz
# Extracted: 066.tar.gz
# Extracted: 112.tar.gz
# Extracted: 015.tar.gz
# Extracted: 061.tar.gz
# Extracted: 047.tar.gz
# Extracted: 108.tar.gz
# Extracted: 053.tar.gz
# Extracted: 011.tar.gz
# Extracted: 043.tar.gz
# Extracted: 063.tar.gz
# Extracted: 072.tar.gz
# Extracted: 017.tar.gz
# Extracted: 087.tar.gz
# Extracted: 074.tar.gz
# Extracted: 009.tar.gz
# Extracted: 070.tar.gz
# Extracted: 059.tar.gz
# Extracted: 008.tar.gz
# Extracted: 049.tar.gz
# Extracted: 010.tar.gz
# Extracted: 100.tar.gz
# Extracted: 114.tar.gz
# Extracted: 004.tar.gz
# Extracted: 083.tar.gz
# Extracted: 056.tar.gz
# Extracted: 014.tar.gz
# Extracted: 119.tar.gz
# Extracted: 071.tar.gz

# %%
# !rm -rf configs
# !rm -rf datasets
# !rm -rf opengait
# !rm -rf output
# !rm -rf README.md
# !rm -rf .gitignore
# !rm -rf .git

# %%
# !git init
# !git config user.email "you@example.com"
# !git config user.name "Your Name"
# !git remote add origin https://github.com/msdsn/OpenGait.git
# !git fetch origin
# !git merge origin/master --allow-unrelated-histories
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 1775, done.
# remote: Counting objects: 100% (760/760), done.
# remote: Compressing objects: 100% (252/252), done.
# remote: Total 1775 (delta 608), reused 551 (delta 503), pack-reused 1015 (from 1)
# Receiving objects: 100% (1775/1775), 20.18 MiB | 35.20 MiB/s, done.
# Resolving deltas: 100% (1097/1097), done.
# From https://github.com/msdsn/OpenGait
#  * [new branch]      master     -> origin/master

# %%
#!git pull origin master

# %%
# !python "./datasets/pretreatment.py" --input_path "/content/GaitDatasetB/GaitDatasetB-silh" --output_path CASIA-B-pkl
# Out:
# Pretreating: 100% 13593/13593 [08:09<00:00, 27.74folder/s]

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA A100-SXM4-40GB (UUID: GPU-2a8a4619-3ce4-aa3e-1c76-3b2e59cccd56)

# %%
pip install tqdm pyyaml tensorboard opencv-python kornia einops torchvision
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Collecting kornia
#   Downloading kornia-0.7.3-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.8.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.0+cu121)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.7)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.4)
# Collecting kornia-rs>=0.1.0 (from kornia)
#   Downloading kornia_rs-0.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kornia) (24.1)
# Requirement already satisfied: torch>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from kornia) (2.5.0+cu121)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.9.1->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Downloading kornia-0.7.3-py2.py3-none-any.whl (833 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 833.3/833.3 kB 13.4 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.7 MB/s eta 0:00:00
# Installing collected packages: kornia-rs, kornia
# Successfully installed kornia-0.7.3 kornia-rs-0.1.5

# %%
#!export PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# %%
# !CUDA_VISIBLE_DEVICES=0 python -m torch.distributed.launch --nproc_per_node=1 opengait/main.py --cfgs ./configs/resnet50/resnet50.yaml --phase train
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/distributed/launch.py:208: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   main()
# 2024-10-24 11:56:30.523655: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-24 11:56:30.541623: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-24 11:56:30.563208: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-24 11:56:30.569698: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-24 11:56:30.585427: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-24 11:56:31.881570: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2024-10-24 11:56:33] [INFO]: {'find_unused_parameters': False, 'enable_float16': True, 'with_test': False, 'fix_BN': False, 'log_iter': 100, 'restore_ckpt_strict': True, 'optimizer_reset': False, 'scheduler_reset': False, 'restore_hint': 0, 'save_iter': 8000, 'save_name': 'GaitBase_DA', 'sync_BN': True, 'total_iter': 8000, 'sampler': {'batch_shuffle': True, 'batch_size': [8, 16], 'frames_num_fixed': 30, 'frames_num_max': 40, 'frames_num_min': 20, 'sample_type': 'fixed_unordered', 'type': 'TripletSampler'}, 'transform': [{'type': 'Compose', 'trf_cfg': [{'type': 'BaseSilCuttingTransform'}, {'type': 'RandomRotate', 'prob': 0.3}, {'type': 'RandomErasing', 'prob': 0.3}]}]}
# [2024-10-24 11:56:33] [INFO]: {'model': 'ResNet50', 'backbone_cfg': {'type': 'ResNet50', 'block': 'BasicBlock', 'channels': [64, 128, 256, 512], 'layers': [1, 1, 1, 1], 'strides': [1, 2, 2, 1], 'maxpool': False}, 'SeparateFCs': {'in_channels': 512, 'out_channels': 256, 'parts_num': 16}, 'SeparateBNNecks': {'class_num': 74, 'in_channels': 256, 'parts_num': 16}, 'bin_num': [16]}
# /content/opengait/modeling/base_model.py:141: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.Scaler = GradScaler()
# [2024-10-24 11:56:34] [INFO]: {'dataset_name': 'CASIA-B', 'dataset_root': './CASIA-B-pkl', 'num_workers': 1, 'dataset_partition': './datasets/CASIA-B/CASIA-B.json', 'remove_no_gallery': False, 'cache': False, 'test_dataset_name': 'CASIA-B'}
# [2024-10-24 11:56:34] [INFO]: -------- Train Pid List --------
# [2024-10-24 11:56:34] [INFO]: [001, 002, ..., 074]
# [2024-10-24 11:56:34] [INFO]: {'lr': 0.1, 'momentum': 0.9, 'solver': 'SGD', 'weight_decay': 0.0005}
# [2024-10-24 11:56:34] [INFO]: {'gamma': 0.1, 'milestones': [2000, 4000, 5000], 'scheduler': 'MultiStepLR'}
# [2024-10-24 11:56:34] [INFO]: Parameters Count: 24.19985M
# [2024-10-24 11:56:34] [INFO]: Model Initialization Finished!
# /content/opengait/modeling/base_model.py:407: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=model.engine_cfg['enable_float16']):
# [2024-10-24 11:58:47] [INFO]: Iteration 00100, Cost 134.10s, triplet_loss=0.5324, triplet_hard_loss=3.7109, triplet_loss_num=141735.4531, triplet_mean_dist=0.9733, softmax_loss=4.6645, softmax_accuracy=0.0431
# [2024-10-24 12:00:58] [INFO]: Iteration 00200, Cost 131.02s, triplet_loss=0.2454, triplet_hard_loss=1.2630, triplet_loss_num=161183.9375, triplet_mean_dist=0.4883, softmax_loss=3.9553, softmax_accuracy=0.1056
# [2024-10-24 12:03:08] [INFO]: Iteration 00300, Cost 130.60s, triplet_loss=0.2206, triplet_hard_loss=1.0846, triplet_loss_num=158385.7812, triplet_mean_dist=0.5097, softmax_loss=3.4964, softmax_accuracy=0.1950
# [2024-10-24 12:05:19] [INFO]: Iteration 00400, Cost 130.74s, triplet_loss=0.2137, triplet_hard_loss=1.0720, triplet_loss_num=146201.8125, triplet_mean_dist=0.5914, softmax_loss=3.1659, softmax_accuracy=0.2752
# [2024-10-24 12:07:30] [INFO]: Iteration 00500, Cost 130.37s, triplet_loss=0.2037, triplet_hard_loss=1.0685, triplet_loss_num=125957.7109, triplet_mean_dist=0.7171, softmax_loss=2.8147, softmax_accuracy=0.3819
# [2024-10-24 12:09:40] [INFO]: Iteration 00600, Cost 130.70s, triplet_loss=0.1976, triplet_hard_loss=1.1133, triplet_loss_num=101784.7188, triplet_mean_dist=0.8924, softmax_loss=2.5407, softmax_accuracy=0.4637
# [2024-10-24 12:11:51] [INFO]: Iteration 00700, Cost 130.73s, triplet_loss=0.1938, triplet_hard_loss=1.1182, triplet_loss_num=83147.6719, triplet_mean_dist=1.0509, softmax_loss=2.3308, softmax_accuracy=0.5381
# [2024-10-24 12:14:02] [INFO]: Iteration 00800, Cost 130.54s, triplet_loss=0.1924, triplet_hard_loss=1.1358, triplet_loss_num=62745.9805, triplet_mean_dist=1.2407, softmax_loss=2.1143, softmax_accuracy=0.6026
# [2024-10-24 12:16:12] [INFO]: Iteration 00900, Cost 130.49s, triplet_loss=0.1936, triplet_hard_loss=1.1916, triplet_loss_num=48872.9453, triplet_mean_dist=1.3965, softmax_loss=1.9652, softmax_accuracy=0.6523
# [2024-10-24 12:18:23] [INFO]: Iteration 01000, Cost 130.93s, triplet_loss=0.1948, triplet_hard_loss=1.1902, triplet_loss_num=43829.9062, triplet_mean_dist=1.4919, softmax_loss=1.8713, softmax_accuracy=0.6880
# [2024-10-24 12:20:33] [INFO]: Iteration 01100, Cost 130.36s, triplet_loss=0.1925, triplet_hard_loss=1.1774, triplet_loss_num=35581.4883, triplet_mean_dist=1.6155, softmax_loss=1.7560, softmax_accuracy=0.7260
# [2024-10-24 12:22:44] [INFO]: Iteration 01200, Cost 130.84s, triplet_loss=0.1955, triplet_hard_loss=1.2002, triplet_loss_num=34309.1289, triplet_mean_dist=1.6801, softmax_loss=1.7225, softmax_accuracy=0.7365
# [2024-10-24 12:24:56] [INFO]: Iteration 01300, Cost 131.30s, triplet_loss=0.1931, triplet_hard_loss=1.1919, triplet_loss_num=28218.2305, triplet_mean_dist=1.7691, softmax_loss=1.6201, softmax_accuracy=0.7726
# [2024-10-24 12:27:06] [INFO]: Iteration 01400, Cost 130.70s, triplet_loss=0.1896, triplet_hard_loss=1.1585, triplet_loss_num=20902.7168, triplet_mean_dist=1.9240, softmax_loss=1.4963, softmax_accuracy=0.8177
# [2024-10-24 12:29:17] [INFO]: Iteration 01500, Cost 131.02s, triplet_loss=0.1898, triplet_hard_loss=1.1556, triplet_loss_num=20182.4102, triplet_mean_dist=1.9439, softmax_loss=1.4611, softmax_accuracy=0.8308
# [2024-10-24 12:31:28] [INFO]: Iteration 01600, Cost 130.90s, triplet_loss=0.1895, triplet_hard_loss=1.1739, triplet_loss_num=18280.9414, triplet_mean_dist=2.0184, softmax_loss=1.4323, softmax_accuracy=0.8388
# [2024-10-24 12:33:39] [INFO]: Iteration 01700, Cost 131.05s, triplet_loss=0.1861, triplet_hard_loss=1.1482, triplet_loss_num=15515.9688, triplet_mean_dist=2.1114, softmax_loss=1.3854, softmax_accuracy=0.8543
# [2024-10-24 12:35:50] [INFO]: Iteration 01800, Cost 130.77s, triplet_loss=0.1884, triplet_hard_loss=1.1458, triplet_loss_num=13514.9463, triplet_mean_dist=2.1864, softmax_loss=1.3671, softmax_accuracy=0.8603
# [2024-10-24 12:38:01] [INFO]: Iteration 01900, Cost 131.02s, triplet_loss=0.1866, triplet_hard_loss=1.1322, triplet_loss_num=12449.2842, triplet_mean_dist=2.2213, softmax_loss=1.3339, softmax_accuracy=0.8728
# [2024-10-24 12:40:13] [INFO]: Iteration 02000, Cost 132.52s, triplet_loss=0.1851, triplet_hard_loss=1.1277, triplet_loss_num=11582.3574, triplet_mean_dist=2.2589, softmax_loss=1.2928, softmax_accuracy=0.8858
# [2024-10-24 12:42:25] [INFO]: Iteration 02100, Cost 131.41s, triplet_loss=0.1673, triplet_hard_loss=0.9862, triplet_loss_num=6336.0820, triplet_mean_dist=2.3862, softmax_loss=1.1476, softmax_accuracy=0.9389
# [2024-10-24 12:44:36] [INFO]: Iteration 02200, Cost 131.26s, triplet_loss=0.1676, triplet_hard_loss=0.9724, triplet_loss_num=4625.4980, triplet_mean_dist=2.5751, softmax_loss=1.0975, softmax_accuracy=0.9541
# [2024-10-24 12:46:48] [INFO]: Iteration 02300, Cost 131.35s, triplet_loss=0.1688, triplet_hard_loss=0.9796, triplet_loss_num=4422.5063, triplet_mean_dist=2.6305, softmax_loss=1.0771, softmax_accuracy=0.9605
# [2024-10-24 12:48:59] [INFO]: Iteration 02400, Cost 131.83s, triplet_loss=0.1705, triplet_hard_loss=1.0009, triplet_loss_num=4080.2637, triplet_mean_dist=2.6954, softmax_loss=1.0688, softmax_accuracy=0.9613
# [2024-10-24 12:51:11] [INFO]: Iteration 02500, Cost 131.29s, triplet_loss=0.1735, triplet_hard_loss=0.9991, triplet_loss_num=3567.7068, triplet_mean_dist=2.7449, softmax_loss=1.0531, softmax_accuracy=0.9665
# [2024-10-24 12:53:22] [INFO]: Iteration 02600, Cost 131.72s, triplet_loss=0.1679, triplet_hard_loss=0.9650, triplet_loss_num=3460.9775, triplet_mean_dist=2.7482, softmax_loss=1.0521, softmax_accuracy=0.9648
# [2024-10-24 12:55:34] [INFO]: Iteration 02700, Cost 131.54s, triplet_loss=0.1737, triplet_hard_loss=0.9845, triplet_loss_num=3407.1382, triplet_mean_dist=2.7865, softmax_loss=1.0458, softmax_accuracy=0.9661
# [2024-10-24 12:57:46] [INFO]: Iteration 02800, Cost 131.67s, triplet_loss=0.1656, triplet_hard_loss=0.9440, triplet_loss_num=3006.3994, triplet_mean_dist=2.8116, softmax_loss=1.0376, softmax_accuracy=0.9679
# [2024-10-24 12:59:57] [INFO]: Iteration 02900, Cost 131.58s, triplet_loss=0.1711, triplet_hard_loss=0.9616, triplet_loss_num=2994.0537, triplet_mean_dist=2.8512, softmax_loss=1.0424, softmax_accuracy=0.9660
# [2024-10-24 13:02:09] [INFO]: Iteration 03000, Cost 131.80s, triplet_loss=0.1677, triplet_hard_loss=0.9452, triplet_loss_num=2887.9832, triplet_mean_dist=2.8154, softmax_loss=1.0311, softmax_accuracy=0.9688
# [2024-10-24 13:04:21] [INFO]: Iteration 03100, Cost 131.70s, triplet_loss=0.1668, triplet_hard_loss=0.9359, triplet_loss_num=2754.2043, triplet_mean_dist=2.8470, softmax_loss=1.0236, softmax_accuracy=0.9714
# [2024-10-24 13:06:32] [INFO]: Iteration 03200, Cost 131.52s, triplet_loss=0.1690, triplet_hard_loss=0.9500, triplet_loss_num=2713.2869, triplet_mean_dist=2.8845, softmax_loss=1.0226, softmax_accuracy=0.9711
# [2024-10-24 13:08:44] [INFO]: Iteration 03300, Cost 131.84s, triplet_loss=0.1711, triplet_hard_loss=0.9518, triplet_loss_num=2644.7039, triplet_mean_dist=2.9009, softmax_loss=1.0228, softmax_accuracy=0.9706
# [2024-10-24 13:10:56] [INFO]: Iteration 03400, Cost 131.95s, triplet_loss=0.1693, triplet_hard_loss=0.9352, triplet_loss_num=2310.9031, triplet_mean_dist=2.9187, softmax_loss=1.0152, softmax_accuracy=0.9721
# [2024-10-24 13:13:08] [INFO]: Iteration 03500, Cost 131.74s, triplet_loss=0.1678, triplet_hard_loss=0.9224, triplet_loss_num=2273.0212, triplet_mean_dist=2.9515, softmax_loss=1.0158, softmax_accuracy=0.9721
# [2024-10-24 13:15:19] [INFO]: Iteration 03600, Cost 131.77s, triplet_loss=0.1682, triplet_hard_loss=0.9256, triplet_loss_num=2261.7957, triplet_mean_dist=2.9679, softmax_loss=1.0151, softmax_accuracy=0.9722
# [2024-10-24 13:17:31] [INFO]: Iteration 03700, Cost 131.89s, triplet_loss=0.1709, triplet_hard_loss=0.9367, triplet_loss_num=2084.0137, triplet_mean_dist=2.9925, softmax_loss=1.0068, softmax_accuracy=0.9735
# [2024-10-24 13:19:43] [INFO]: Iteration 03800, Cost 132.11s, triplet_loss=0.1712, triplet_hard_loss=0.9401, triplet_loss_num=2076.2893, triplet_mean_dist=2.9501, softmax_loss=1.0019, softmax_accuracy=0.9753
# [2024-10-24 13:21:55] [INFO]: Iteration 03900, Cost 131.67s, triplet_loss=0.1698, triplet_hard_loss=0.9218, triplet_loss_num=2135.3850, triplet_mean_dist=2.9686, softmax_loss=0.9998, softmax_accuracy=0.9762
# [2024-10-24 13:24:08] [INFO]: Iteration 04000, Cost 133.04s, triplet_loss=0.1675, triplet_hard_loss=0.9221, triplet_loss_num=1955.9832, triplet_mean_dist=2.9932, softmax_loss=1.0019, softmax_accuracy=0.9749
# [2024-10-24 13:26:20] [INFO]: Iteration 04100, Cost 131.55s, triplet_loss=0.1604, triplet_hard_loss=0.8557, triplet_loss_num=1461.0431, triplet_mean_dist=3.0064, softmax_loss=0.9829, softmax_accuracy=0.9804
# [2024-10-24 13:28:31] [INFO]: Iteration 04200, Cost 131.78s, triplet_loss=0.1606, triplet_hard_loss=0.8457, triplet_loss_num=1395.1488, triplet_mean_dist=3.0572, softmax_loss=0.9771, softmax_accuracy=0.9815
# [2024-10-24 13:30:43] [INFO]: Iteration 04300, Cost 131.69s, triplet_loss=0.1546, triplet_hard_loss=0.8047, triplet_loss_num=1200.4407, triplet_mean_dist=3.0892, softmax_loss=0.9707, softmax_accuracy=0.9833
# [2024-10-24 13:32:55] [INFO]: Iteration 04400, Cost 132.00s, triplet_loss=0.1566, triplet_hard_loss=0.8120, triplet_loss_num=1184.1937, triplet_mean_dist=3.1130, softmax_loss=0.9693, softmax_accuracy=0.9828
# [2024-10-24 13:35:07] [INFO]: Iteration 04500, Cost 131.87s, triplet_loss=0.1576, triplet_hard_loss=0.8117, triplet_loss_num=1147.4025, triplet_mean_dist=3.1058, softmax_loss=0.9646, softmax_accuracy=0.9843
# [2024-10-24 13:37:19] [INFO]: Iteration 04600, Cost 131.73s, triplet_loss=0.1545, triplet_hard_loss=0.8048, triplet_loss_num=1100.2662, triplet_mean_dist=3.1219, softmax_loss=0.9670, softmax_accuracy=0.9827
# [2024-10-24 13:39:31] [INFO]: Iteration 04700, Cost 131.87s, triplet_loss=0.1561, triplet_hard_loss=0.7992, triplet_loss_num=1038.3325, triplet_mean_dist=3.1811, softmax_loss=0.9656, softmax_accuracy=0.9839
# [2024-10-24 13:41:42] [INFO]: Iteration 04800, Cost 131.81s, triplet_loss=0.1583, triplet_hard_loss=0.8134, triplet_loss_num=1068.2562, triplet_mean_dist=3.1701, softmax_loss=0.9629, softmax_accuracy=0.9840
# [2024-10-24 13:43:54] [INFO]: Iteration 04900, Cost 131.65s, triplet_loss=0.1616, triplet_hard_loss=0.8310, triplet_loss_num=1187.3494, triplet_mean_dist=3.1557, softmax_loss=0.9686, softmax_accuracy=0.9819
# [2024-10-24 13:46:06] [INFO]: Iteration 05000, Cost 131.68s, triplet_loss=0.1543, triplet_hard_loss=0.7794, triplet_loss_num=910.6331, triplet_mean_dist=3.1876, softmax_loss=0.9612, softmax_accuracy=0.9848
# [2024-10-24 13:48:18] [INFO]: Iteration 05100, Cost 131.95s, triplet_loss=0.1563, triplet_hard_loss=0.7871, triplet_loss_num=928.7969, triplet_mean_dist=3.2299, softmax_loss=0.9632, softmax_accuracy=0.9840
# [2024-10-24 13:50:30] [INFO]: Iteration 05200, Cost 132.10s, triplet_loss=0.1617, triplet_hard_loss=0.8382, triplet_loss_num=1003.0644, triplet_mean_dist=3.2286, softmax_loss=0.9605, softmax_accuracy=0.9848
# [2024-10-24 13:52:41] [INFO]: Iteration 05300, Cost 131.61s, triplet_loss=0.1624, triplet_hard_loss=0.8362, triplet_loss_num=1092.3456, triplet_mean_dist=3.2244, softmax_loss=0.9669, softmax_accuracy=0.9823
# [2024-10-24 13:54:53] [INFO]: Iteration 05400, Cost 131.90s, triplet_loss=0.1528, triplet_hard_loss=0.7863, triplet_loss_num=923.1119, triplet_mean_dist=3.2130, softmax_loss=0.9635, softmax_accuracy=0.9837
# [2024-10-24 13:57:05] [INFO]: Iteration 05500, Cost 131.74s, triplet_loss=0.1598, triplet_hard_loss=0.8090, triplet_loss_num=992.2932, triplet_mean_dist=3.2244, softmax_loss=0.9631, softmax_accuracy=0.9827
# [2024-10-24 13:59:17] [INFO]: Iteration 05600, Cost 131.91s, triplet_loss=0.1587, triplet_hard_loss=0.8188, triplet_loss_num=1120.5325, triplet_mean_dist=3.2083, softmax_loss=0.9659, softmax_accuracy=0.9835
# [2024-10-24 14:01:29] [INFO]: Iteration 05700, Cost 131.84s, triplet_loss=0.1584, triplet_hard_loss=0.8040, triplet_loss_num=1056.4144, triplet_mean_dist=3.1893, softmax_loss=0.9635, softmax_accuracy=0.9833
# [2024-10-24 14:03:41] [INFO]: Iteration 05800, Cost 131.95s, triplet_loss=0.1563, triplet_hard_loss=0.7814, triplet_loss_num=875.4050, triplet_mean_dist=3.2146, softmax_loss=0.9576, softmax_accuracy=0.9855
# [2024-10-24 14:05:52] [INFO]: Iteration 05900, Cost 131.66s, triplet_loss=0.1540, triplet_hard_loss=0.7740, triplet_loss_num=884.0137, triplet_mean_dist=3.2330, softmax_loss=0.9594, softmax_accuracy=0.9848
# [2024-10-24 14:08:05] [INFO]: Iteration 06000, Cost 132.83s, triplet_loss=0.1531, triplet_hard_loss=0.7730, triplet_loss_num=910.2125, triplet_mean_dist=3.2309, softmax_loss=0.9610, softmax_accuracy=0.9845
# [2024-10-24 14:10:17] [INFO]: Iteration 06100, Cost 131.58s, triplet_loss=0.1550, triplet_hard_loss=0.7997, triplet_loss_num=936.6131, triplet_mean_dist=3.2117, softmax_loss=0.9615, softmax_accuracy=0.9841
# [2024-10-24 14:12:28] [INFO]: Iteration 06200, Cost 131.61s, triplet_loss=0.1558, triplet_hard_loss=0.7812, triplet_loss_num=910.1325, triplet_mean_dist=3.2226, softmax_loss=0.9605, softmax_accuracy=0.9844
# [2024-10-24 14:14:40] [INFO]: Iteration 06300, Cost 131.39s, triplet_loss=0.1537, triplet_hard_loss=0.7728, triplet_loss_num=909.0637, triplet_mean_dist=3.2078, softmax_loss=0.9567, softmax_accuracy=0.9857
# [2024-10-24 14:16:52] [INFO]: Iteration 06400, Cost 131.68s, triplet_loss=0.1559, triplet_hard_loss=0.7898, triplet_loss_num=921.0544, triplet_mean_dist=3.2249, softmax_loss=0.9596, softmax_accuracy=0.9850
# [2024-10-24 14:19:03] [INFO]: Iteration 06500, Cost 131.58s, triplet_loss=0.1537, triplet_hard_loss=0.7698, triplet_loss_num=888.4363, triplet_mean_dist=3.2300, softmax_loss=0.9555, softmax_accuracy=0.9859
# [2024-10-24 14:21:15] [INFO]: Iteration 06600, Cost 131.88s, triplet_loss=0.1570, triplet_hard_loss=0.8004, triplet_loss_num=958.3412, triplet_mean_dist=3.2129, softmax_loss=0.9599, softmax_accuracy=0.9854
# [2024-10-24 14:23:27] [INFO]: Iteration 06700, Cost 131.65s, triplet_loss=0.1539, triplet_hard_loss=0.7726, triplet_loss_num=860.1763, triplet_mean_dist=3.2374, softmax_loss=0.9571, softmax_accuracy=0.9857
# [2024-10-24 14:25:39] [INFO]: Iteration 06800, Cost 132.56s, triplet_loss=0.1559, triplet_hard_loss=0.7930, triplet_loss_num=935.3650, triplet_mean_dist=3.2244, softmax_loss=0.9607, softmax_accuracy=0.9843
# [2024-10-24 14:27:52] [INFO]: Iteration 06900, Cost 132.40s, triplet_loss=0.1565, triplet_hard_loss=0.7843, triplet_loss_num=890.3237, triplet_mean_dist=3.2429, softmax_loss=0.9571, softmax_accuracy=0.9843
# [2024-10-24 14:30:04] [INFO]: Iteration 07000, Cost 132.58s, triplet_loss=0.1588, triplet_hard_loss=0.8020, triplet_loss_num=957.8019, triplet_mean_dist=3.2194, softmax_loss=0.9571, softmax_accuracy=0.9851
# [2024-10-24 14:32:17] [INFO]: Iteration 07100, Cost 132.47s, triplet_loss=0.1592, triplet_hard_loss=0.8100, triplet_loss_num=965.8262, triplet_mean_dist=3.2189, softmax_loss=0.9583, softmax_accuracy=0.9850
# [2024-10-24 14:34:29] [INFO]: Iteration 07200, Cost 132.47s, triplet_loss=0.1544, triplet_hard_loss=0.7945, triplet_loss_num=955.2150, triplet_mean_dist=3.2189, softmax_loss=0.9618, softmax_accuracy=0.9840
# [2024-10-24 14:36:42] [INFO]: Iteration 07300, Cost 132.39s, triplet_loss=0.1579, triplet_hard_loss=0.7935, triplet_loss_num=960.1806, triplet_mean_dist=3.2269, softmax_loss=0.9605, softmax_accuracy=0.9847
# [2024-10-24 14:38:54] [INFO]: Iteration 07400, Cost 132.44s, triplet_loss=0.1547, triplet_hard_loss=0.7683, triplet_loss_num=886.2919, triplet_mean_dist=3.2382, softmax_loss=0.9564, softmax_accuracy=0.9850
# [2024-10-24 14:41:06] [INFO]: Iteration 07500, Cost 132.07s, triplet_loss=0.1522, triplet_hard_loss=0.7574, triplet_loss_num=831.4182, triplet_mean_dist=3.2550, softmax_loss=0.9558, softmax_accuracy=0.9857
# [2024-10-24 14:43:18] [INFO]: Iteration 07600, Cost 132.16s, triplet_loss=0.1567, triplet_hard_loss=0.7895, triplet_loss_num=879.7637, triplet_mean_dist=3.2535, softmax_loss=0.9559, softmax_accuracy=0.9850
# [2024-10-24 14:45:30] [INFO]: Iteration 07700, Cost 131.98s, triplet_loss=0.1566, triplet_hard_loss=0.7867, triplet_loss_num=888.4400, triplet_mean_dist=3.2423, softmax_loss=0.9570, softmax_accuracy=0.9849
# [2024-10-24 14:47:42] [INFO]: Iteration 07800, Cost 131.80s, triplet_loss=0.1579, triplet_hard_loss=0.7926, triplet_loss_num=920.6506, triplet_mean_dist=3.2451, softmax_loss=0.9550, softmax_accuracy=0.9863
# [2024-10-24 14:49:54] [INFO]: Iteration 07900, Cost 131.57s, triplet_loss=0.1567, triplet_hard_loss=0.7897, triplet_loss_num=865.8331, triplet_mean_dist=3.2405, softmax_loss=0.9545, softmax_accuracy=0.9859
# [2024-10-24 14:52:06] [INFO]: Iteration 08000, Cost 132.91s, triplet_loss=0.1530, triplet_hard_loss=0.7740, triplet_loss_num=840.7881, triplet_mean_dist=3.2616, softmax_loss=0.9534, softmax_accuracy=0.9865
# [rank0]:[W1024 14:52:10.391152504 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())

# %%
# prompt: zip all files in output folder

import shutil

def zip_folder(folder_path, output_filename):
  shutil.make_archive(output_filename, 'zip', folder_path)

zip_folder("/content/output", "output_filesgaitbase")

# %%
# !CUDA_VISIBLE_DEVICES=0 python -m torch.distributed.launch --nproc_per_node=1 opengait/main.py --cfgs ./configs/resnet50/resnet50.yaml --phase test
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/distributed/launch.py:208: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   main()
# 2024-10-24 15:13:00.928658: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-24 15:13:00.946305: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-24 15:13:00.967320: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-24 15:13:00.973759: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-24 15:13:00.989103: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-24 15:13:02.267581: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2024-10-24 15:13:04] [INFO]: {'enable_float16': True, 'restore_ckpt_strict': True, 'restore_hint': 8000, 'save_name': 'GaitBase_DA', 'eval_func': 'evaluate_indoor_dataset', 'sampler': {'batch_size': 16, 'sample_type': 'fixed_unordered', 'type': 'InferenceSampler', 'batch_shuffle': False, 'frames_num_fixed': 30, 'frames_num_max': 40, 'frames_num_min': 20}, 'transform': [{'type': 'BaseSilCuttingTransform'}], 'metric': 'euc', 'cross_view_gallery': False}
# [2024-10-24 15:13:04] [INFO]: {'model': 'ResNet50', 'backbone_cfg': {'type': 'ResNet50', 'block': 'BasicBlock', 'channels': [64, 128, 256, 512], 'layers': [1, 1, 1, 1], 'strides': [1, 2, 2, 1], 'maxpool': False}, 'SeparateFCs': {'in_channels': 512, 'out_channels': 256, 'parts_num': 16}, 'SeparateBNNecks': {'class_num': 74, 'in_channels': 256, 'parts_num': 16}, 'bin_num': [16]}
# [2024-10-24 15:13:04] [INFO]: {'dataset_name': 'CASIA-B', 'dataset_root': './CASIA-B-pkl', 'num_workers': 1, 'dataset_partition': './datasets/CASIA-B/CASIA-B.json', 'remove_no_gallery': False, 'cache': False, 'test_dataset_name': 'CASIA-B'}
# [2024-10-24 15:13:04] [INFO]: -------- Test Pid List --------
# [2024-10-24 15:13:04] [INFO]: [075, 076, ..., 124]
# /content/opengait/modeling/base_model.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(save_name, map_location=torch.device(
# [2024-10-24 15:13:05] [INFO]: Restore Parameters from output/CASIA-B/ResNet50/GaitBase_DA/checkpoints/GaitBase_DA-08000.pt !!!
# [2024-10-24 15:13:05] [INFO]: Parameters Count: 24.19985M
# [2024-10-24 15:13:05] [INFO]: Model Initialization Finished!
# Transforming:   0% 0/5485 [00:00<?, ?it/s]/content/opengait/modeling/base_model.py:381: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.engine_cfg['enable_float16']):
# Transforming: 100% 5485/5485 [00:19<00:00, 281.80it/s]
# [2024-10-24 15:13:27] [INFO]: ===Rank-1 (Exclude identical-view cases)===
# [2024-10-24 15:13:27] [INFO]: NM@R1: [78.00 90.00 95.40 93.00 84.80 83.30 86.30 91.10 94.10 89.40 77.10]
# [2024-10-24 15:13:27] [INFO]: BG@R1: [67.90 82.60 87.70 85.96 77.60 73.70 77.80 82.60 87.20 79.80 65.70]
# [2024-10-24 15:13:27] [INFO]: CL@R1: [50.70 63.10 73.40 72.20 65.10 60.60 65.80 66.90 66.40 57.00 43.60]
# [2024-10-24 15:13:27] [INFO]: NM@R1: 87.50%	BG@R1: 78.96%	CL@R1: 62.25%
# [rank0]:[W1024 15:13:27.270030127 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())
